# %% [markdown]
# <a href="https://colab.research.google.com/github/Code-Cognito/Varsity_Work/blob/main/Drug_Addiction_1429.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/MyDrive/DataSets/Bangladeshi_Drug_Use_Dataset.csv')
df.head()
# Out:
#     Age Gender Education (last/ongoing) With whom do you live?  \
# 0  21.0   Male            Undergraduate                 Family
# 1  22.0   Male            Undergraduate            Hall/Hostel
# 2  21.0   Male            Undergraduate                 Family
# 3  22.0   Male            Undergraduate                 Family
# 4  23.0   Male            Undergraduate            Hall/Hostel
#
#   What is your thinking about drug?  \
# 0             Disease, should avoid
# 1                      Should avoid
# 2             Disease, should avoid
# 3                      Should avoid
# 4        Social trend, should avoid
#
#   With whom do you spend most of your times? Did you ever fail in your life?  \
# 0                           Family/Relatives                             Yes
# 1                                      Alone                             Yes
# 2                           Family/Relatives                             Yes
# ...

# %%
df.shape
# Out:
# (1501, 19)

# %%
df.columns.tolist()
# Out:
# ['Age',
#  'Gender',
#  'Education',
#  'Living Situation',
#  'Attitude Towards Drugs',
#  'Social Connections',
#  'Past Failures',
#  'Suicidal Thoughts',
#  'Family Relationships',
#  'Family Finances',
#  'Addicted Friends',
#  'Family Addiction',
#  'Workplace Satisfaction',
#  'Legal Cases',
#  'Living with Drug User',
#  'Drug Use Factors',
#  'Past Drug Use',
#  'First Drug Name',
#  'First Drug Age',
#  'Frequency of Drug Use',
#  'Current Drug Use',
#  'Occasions for Drug Use',
#  'Willingness to Try Drugs',
#  'Drug Control',
#  'Reasons for Starting',
#  'Guilt After Drug Use']

# %%
df.columns = [
    'Age',
    'Gender',
    'Education',
    'Living Situation',
    'Attitude Towards Drugs',
    'Social Connections',
    'Past Failures',
    'Suicidal Thoughts',
    'Family Relationships',
    'Family Finances',
    'Addicted Friends',
    'Family Addiction',
    'Workplace Satisfaction',
    'Legal Cases',
    'Living with Drug User',
    'Drug Use Factors',
    'Past Drug Use',
    'First Drug Name',
    'First Drug Age',
    'Frequency of Drug Use',
    'Current Drug Use',
    'Occasions for Drug Use',
    'Willingness to Try Drugs',
    'Drug Control',
    'Reasons for Starting',
    'Guilt After Drug Use']

# %%
df.isnull().sum()
# Out:
# Age                          71
# Gender                        0
# Education                    24
# Living Situation              0
# Attitude Towards Drugs        0
# Social Connections            0
# Past Failures                24
# Suicidal Thoughts             0
# Family Relationships         23
# Family Finances               0
# Addicted Friends            755
# Family Addiction             24
# Workplace Satisfaction       70
# Legal Cases                  24
# Living with Drug User        24
# Drug Use Factors            119
# Past Drug Use                48
# First Drug Name             357
# First Drug Age              640
# Frequency of Drug Use       285
# Current Drug Use            310
# Occasions for Drug Use      308
# Willingness to Try Drugs    120
# Drug Control                215
# Reasons for Starting        944
# Guilt After Drug Use        684
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
cols = df.columns.tolist()
for col in cols:
  df[col] = df[col].fillna(df[col].mode()[0])

# %%
df.isnull().sum()
# Out:
# Age                         0
# Gender                      0
# Education                   0
# Living Situation            0
# Attitude Towards Drugs      0
# Social Connections          0
# Past Failures               0
# Suicidal Thoughts           0
# Family Relationships        0
# Family Finances             0
# Addicted Friends            0
# Family Addiction            0
# Workplace Satisfaction      0
# Legal Cases                 0
# Living with Drug User       0
# Drug Use Factors            0
# Past Drug Use               0
# First Drug Name             0
# First Drug Age              0
# Frequency of Drug Use       0
# Current Drug Use            0
# Occasions for Drug Use      0
# Willingness to Try Drugs    0
# Drug Control                0
# Reasons for Starting        0
# Guilt After Drug Use        0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >
